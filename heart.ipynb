# %% [markdown]
# cv.imread()
# np.fft.fft2()
# np.fft.fftshift()
# plt.subplot(1,2,1)
# plt.title()
# plt.imshow()
# cv2.addWeighted(image, alpha, watermark_resized, beta, gamma)
# np.stack(images, axis=0)
# np.mean(stacked_images, axis=0).astype(np.uint8)
# np.argsort()
#
# histogram, bins = np.histogram(image.flatten(), bins=256, range=[0, 256])
# plt.hist(negative.ravel(), bins=256, range=(0, 256), color='black', alpha=0.7)
# histogram.cumsum()
# np.interp(image.flatten(), bins[:-1], cdf_normalized).reshape(image.shape)
# np.uint8(equalized_image)
# pip install opencv-python
# .astype(np.float32)
# cv2.normalize(log_image, None, 0, 255, cv2.NORM_MINMAX)

# %%
import pandas as pd
data = pd.DataFrame(
    [[1, 2, 3],
     [4, 5, 6],
     [7, 8, 9]],
    columns=['Column1', 'Column2', 'Column3'],  
    index=['Row1', 'Row2', 'Row3']
    )

# %%
print("element: ",data.iloc[1,1])
print("row: ",data.iloc[1],sep='\n')
print("column: ",data.iloc[:,1],sep='\n')
print("row by name: ",data.loc['Row1'],sep='\n')
print("column by name: ",data['Column1'],sep='\n')
# Out:
# element:  5
# row:
# Column1    4
# Column2    5
# Column3    6
# Name: Row2, dtype: int64
# column:
# Row1    2
# Row2    5
# Row3    8
# Name: Column2, dtype: int64
# row by name:
# Column1    1
# Column2    2
# Column3    3
# Name: Row1, dtype: int64
# column by name:
# Row1    1
# Row2    4
# Row3    7
# Name: Column1, dtype: int64

# %% [markdown]
# Digital Image and Video Processing

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
image = cv.imread("/home/jarvis/codebase_II/semester7/default_image.png",cv.IMREAD_GRAYSCALE)
dft = np.fft.fft2(image)
dft_shift = np.fft.fftshift(dft) 

dft_image = 20 * np.log(np.abs(dft_shift))
logs = 2*np.log(image+1)

plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(image, cmap = 'gray')
plt.axis('off')

plt.subplot(1,3,2)
plt.title('DFT Image')
plt.imshow(dft_image, cmap = 'gray')
plt.axis('off')

plt.subplot(1,3,3)
plt.title('Log transformation')
plt.imshow(logs, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

image = cv.imread("/home/jarvis/codebase_II/semester7/default_image.png",cv.IMREAD_GRAYSCALE)
dft_image = np.fft.fft2(image)
dft_shift = np.fft.fftshift(dft_image)
dft = 20*np.log(np.abs(dft_shift))

plt.subplot(1,2,1)
plt.title("original image")
plt.imshow(image,cmap="gray")
plt.axis("off")

plt.subplot(1,2,2)
plt.title("dft image")
plt.imshow(dft,cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 750.5, 660.5, -0.5)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
